# %%
print("A: imports start")

import torch
import torchvision
import cv2
import numpy as np
from PIL import Image

print("B: imports done")

# image_runner.py 맨 위쪽 설정들 복붙
# 예: DEVICE 설정, 경로 설정 등
print("C: config done")
# Out:
# A: imports start
# B: imports done
# C: config done

# %%
print("D: model load before")

# image_runner.py에서 모델 로드하는 부분만 복붙
# ex)
# model = MyModel(...)
# model.load_state_dict(torch.load("..."))
# model.eval()

print("E: model load after")
# Out:
# D: model load before
# E: model load after

# %%
# %env PYTHONFAULTHANDLER=1
# !python runner/image_runner.py
# Out:
# env: PYTHONFAULTHANDLER=1
# python: can't open file '/Users/ryeong/MLPJ/runner/runner/image_runner.py': [Errno 2] No such file or directory

# %%
import os
os.getcwd()
# Out:
# '/Users/ryeong/MLPJ/runner'
